# %%
import pandas as pd

# Cargar los archivos usando la ruta correcta
level1_df = pd.read_excel('level1.xlsx')
level1_df1=level1_df.iloc[:,[0,1,2,4,6,8,10]]
level1_df1
level1_df2=level1_df1.drop([0,1,2,4,5])
level1_df2
new_header=level1_df2.iloc[0]
new_header
level1_df2.columns = new_header
level1_df2.drop(level1_df2.index[0], inplace=True)
level1_df2= level1_df2.rename(columns={'Expected years of schooling': 'EXPECT', 'Gross national income (GNI) per capita': 'GNI',"HDI rank":"HDI 2020","Life expectancy at birth":"LIFE"})
styled_level1_df2 = level1_df2.style.format({'EXPECT': "{:,.1f}", 'GNI': "{:,.0f}", 'HDI 2020': "{:.3f}", 'LIFE': "{:,.1f}"})
styled_level1_df2
# Out:
# <style type="text/css">
# </style>
# <table id="T_e32e8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >3</th>
#       <th id="T_e32e8_level0_col0" class="col_heading level0 col0" >HDI 2020</th>
#       <th id="T_e32e8_level0_col1" class="col_heading level0 col1" >Country</th>
#       <th id="T_e32e8_level0_col2" class="col_heading level0 col2" >Human Development Index (HDI) </th>
#       <th id="T_e32e8_level0_col3" class="col_heading level0 col3" >LIFE</th>
#       <th id="T_e32e8_level0_col4" class="col_heading level0 col4" >EXPECT</th>
#       <th id="T_e32e8_level0_col5" class="col_heading level0 col5" >Mean years of schooling</th>
#       <th id="T_e32e8_level0_col6" class="col_heading level0 col6" >GNI</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e32e8_level0_row0" class="row_heading level0 row0" >6</th>
#       <td id="T_e32e8_row0_col0" class="data row0 col0" >1.000</td>
# ...

# %%
import pandas as pd

# Cargar los archivos usando la ruta correcta
level2_df = pd.read_excel('level2.xlsx')
level2_df=level2_df.iloc[:,[0,1,2,3,4,5,7]]
level2_df= level2_df.drop(index=0)
level2_df= level2_df.drop(index=1)
level2_df= level2_df.rename(columns={'Expected years of schooling': 'EXPECT', 'Gross national income (GNI) per capita': 'GNI',"HDI rank":"HDI 2020","Life expectancy at birth":"LIFE"})
styled_level2_df = level2_df.style.format({'EXPECT': "{:,.1f}", 'GNI': "{:,.0f}", 'HDI 2020': "{:.3f}", 'LIFE': "{:,.1f}"})
styled_level2_df
# Out:
# <style type="text/css">
# </style>
# <table id="T_b8d9d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b8d9d_level0_col0" class="col_heading level0 col0" >HDI 2020</th>
#       <th id="T_b8d9d_level0_col1" class="col_heading level0 col1" >Country</th>
#       <th id="T_b8d9d_level0_col2" class="col_heading level0 col2" >Human Development Index (HDI) </th>
#       <th id="T_b8d9d_level0_col3" class="col_heading level0 col3" >LIFE</th>
#       <th id="T_b8d9d_level0_col4" class="col_heading level0 col4" >EXPECT</th>
#       <th id="T_b8d9d_level0_col5" class="col_heading level0 col5" >Mean years of schooling</th>
#       <th id="T_b8d9d_level0_col6" class="col_heading level0 col6" >GNI</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b8d9d_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_b8d9d_row0_col0" class="data row0 col0" >67.000</td>
# ...

# %%
import pandas as pd
level3_df = pd.read_excel('level3.xlsx')
level3_df=level3_df.iloc[:,[0,1,2,4,6,8,10]]
level3_df= level3_df.drop(index=1)
level3_df= level3_df.drop(index=0)
level3_df= level3_df.rename(columns={'Expected years of schooling': 'EXPECT', 'Gross national income (GNI) per capita': 'GNI',"HDI rank":"HDI 2020","Life expectancy at birth":"LIFE"})
styled_level3_df = level3_df.style.format({'EXPECT': "{:,.1f}", 'GNI': "{:,.0f}", 'HDI 2020': "{:.3f}", 'LIFE': "{:,.1f}"})
styled_level3_df
# Out:
# <style type="text/css">
# </style>
# <table id="T_ca1f6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ca1f6_level0_col0" class="col_heading level0 col0" >HDI 2020</th>
#       <th id="T_ca1f6_level0_col1" class="col_heading level0 col1" >Country</th>
#       <th id="T_ca1f6_level0_col2" class="col_heading level0 col2" >Human Development Index (HDI) </th>
#       <th id="T_ca1f6_level0_col3" class="col_heading level0 col3" >LIFE</th>
#       <th id="T_ca1f6_level0_col4" class="col_heading level0 col4" >EXPECT</th>
#       <th id="T_ca1f6_level0_col5" class="col_heading level0 col5" >Mean years of schooling</th>
#       <th id="T_ca1f6_level0_col6" class="col_heading level0 col6" >GNI</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ca1f6_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_ca1f6_row0_col0" class="data row0 col0" >116.000</td>
# ...

# %%
import pandas as pd

# Cargar los archivos usando la ruta correcta
level4_df = pd.read_excel('level4.xlsx')
level4_df=level4_df.iloc[:,[0,1,3,4,5,6,7]]
level4_df= level4_df.rename(columns={'Expected years of schooling': 'EXPECT', 'Gross national income (GNI) per capita': 'GNI',"HDI rank":"HDI 2020","Life expectancy at birth":"LIFE"})
styled_level4_df = level4_df.style.format({'EXPECT': "{:,.1f}", 'GNI': "{:,.0f}", 'HDI 2020': "{:.3f}", 'LIFE': "{:,.1f}"})
styled_level4_df
# Out:
# <style type="text/css">
# </style>
# <table id="T_9831e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9831e_level0_col0" class="col_heading level0 col0" >HDI 2020</th>
#       <th id="T_9831e_level0_col1" class="col_heading level0 col1" >Country</th>
#       <th id="T_9831e_level0_col2" class="col_heading level0 col2" >Human Development Index (HDI) </th>
#       <th id="T_9831e_level0_col3" class="col_heading level0 col3" >LIFE</th>
#       <th id="T_9831e_level0_col4" class="col_heading level0 col4" >EXPECT</th>
#       <th id="T_9831e_level0_col5" class="col_heading level0 col5" >Mean years of schooling</th>
#       <th id="T_9831e_level0_col6" class="col_heading level0 col6" >GNI</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9831e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9831e_row0_col0" class="data row0 col0" >160.000</td>
# ...

# %%
append_data_df = pd.concat([level1_df2, level2_df, level3_df, level4_df], ignore_index=True)
styled_append_data_df = append_data_df.style.format({'EXPECT': "{:,.1f}", 'GNI': "{:,.0f}", 'HDI 2020': "{:.3f}", 'LIFE': "{:,.1f}"})
styled_append_data_df
# Out:
# <style type="text/css">
# </style>
# <table id="T_9fe3a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9fe3a_level0_col0" class="col_heading level0 col0" >HDI 2020</th>
#       <th id="T_9fe3a_level0_col1" class="col_heading level0 col1" >Country</th>
#       <th id="T_9fe3a_level0_col2" class="col_heading level0 col2" >Human Development Index (HDI) </th>
#       <th id="T_9fe3a_level0_col3" class="col_heading level0 col3" >LIFE</th>
#       <th id="T_9fe3a_level0_col4" class="col_heading level0 col4" >EXPECT</th>
#       <th id="T_9fe3a_level0_col5" class="col_heading level0 col5" >Mean years of schooling</th>
#       <th id="T_9fe3a_level0_col6" class="col_heading level0 col6" >GNI</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9fe3a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9fe3a_row0_col0" class="data row0 col0" >1.000</td>
# ...

# %%
import pandas as pd
country_codes_df = pd.read_excel('countryCODES.xlsx')
country_codes_df['Country'] = country_codes_df['Country'].str.title()
country_codes_df
# Out:
#                  Country                            Officialstatename  \
# 0            Afghanistan          The Islamic Republic of Afghanistan
# 1                Albania                      The Republic of Albania
# 2                Algeria  The People's Democratic Republic of Algeria
# 3                 Angola                       The Republic of Angola
# 4    Antigua And Barbuda                          Antigua and Barbuda
# ..                   ...                                          ...
# 166           Uzbekistan                   The Republic of Uzbekistan
# 167             Viet Nam           The Socialist Republic of Viet Nam
# 168                Yemen                        The Republic of Yemen
# 169               Zambia                       The Republic of Zambia
# 170             Zimbabwe                     The Republic of Zimbabwe
#
#     InternetccTLD iso2 iso3
# 0             .af   AF  AFG
# 1             .al   AL  ALB
# 2             .dz   DZ  DZA
# ...

# %%
merged_df = pd.merge(append_data_df, country_codes_df, on='Country', how='left')
merged_df= merged_df.drop(index=3)
merged_df= merged_df.drop(index=187)
merged_df= merged_df.drop(index=188)
styled_merged_df = merged_df.style.format({'EXPECT': "{:,.1f}", 'GNI': "{:,.0f}", 'HDI 2020': "{:.3f}", 'LIFE': "{:,.1f}"})
styled_merged_df.to_excel('styled_merged_df.xlsx', index=False)  # Guardar en Excel
styled_merged_df
# Out:
# <style type="text/css">
# </style>
# <table id="T_57ee5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_57ee5_level0_col0" class="col_heading level0 col0" >HDI 2020</th>
#       <th id="T_57ee5_level0_col1" class="col_heading level0 col1" >Country</th>
#       <th id="T_57ee5_level0_col2" class="col_heading level0 col2" >Human Development Index (HDI) </th>
#       <th id="T_57ee5_level0_col3" class="col_heading level0 col3" >LIFE</th>
#       <th id="T_57ee5_level0_col4" class="col_heading level0 col4" >EXPECT</th>
#       <th id="T_57ee5_level0_col5" class="col_heading level0 col5" >Mean years of schooling</th>
#       <th id="T_57ee5_level0_col6" class="col_heading level0 col6" >GNI</th>
#       <th id="T_57ee5_level0_col7" class="col_heading level0 col7" >Officialstatename</th>
#       <th id="T_57ee5_level0_col8" class="col_heading level0 col8" >InternetccTLD</th>
# ...

# %%
import pandas as pd
fallecidos_df = pd.read_csv('fallecidosCOVID.csv')
# Asumiendo que la columna concatenada se llama 'columna_concatenada'
columnas = ['FECHA_CORTE','FECHA_FALLECIMIENTO','EDAD_DECLARADA','SEXO','CLASIFICACION_DEF','DEPARTAMENTO','PROVINCIA','DISTRITO','UBIGEO','UUID']
fallecidos_df[columnas] = fallecidos_df['FECHA_CORTE;FECHA_FALLECIMIENTO;EDAD_DECLARADA;SEXO;CLASIFICACION_DEF;DEPARTAMENTO;PROVINCIA;DISTRITO;UBIGEO;UUID'].str.split(';', expand=True)
# Eliminar la columna original
fallecidos_df = fallecidos_df.drop(columns=['FECHA_CORTE;FECHA_FALLECIMIENTO;EDAD_DECLARADA;SEXO;CLASIFICACION_DEF;DEPARTAMENTO;PROVINCIA;DISTRITO;UBIGEO;UUID'])
fallecidos_df
# Out:
#        FECHA_CORTE FECHA_FALLECIMIENTO EDAD_DECLARADA       SEXO  \
# 0         20240317            20220219             63  MASCULINO
# 1         20240317            20210529             74  MASCULINO
# 2         20240317            20210623             72   FEMENINO
# 3         20240317            20210824             85  MASCULINO
# 4         20240317            20210627             46  MASCULINO
# ...            ...                 ...            ...        ...
# 220913    20240317            20200809             77  MASCULINO
# 220914    20240317            20201028             81  MASCULINO
# 220915    20240317            20200515             68   FEMENINO
# 220916    20240317            20210414             66   FEMENINO
# 220917    20240317            20200819             61  MASCULINO
#
#                             CLASIFICACION_DEF DEPARTAMENTO PROVINCIA  \
# 0                         Criterio virológico       TUMBES    TUMBES
# ...

# %%
import pandas as pd

fallecidos_df = pd.read_csv('fallecidosCOVID.csv')

columnas = ['FECHA_CORTE','FECHA_FALLECIMIENTO','EDAD_DECLARADA','SEXO','CLASIFICACION_DEF','DEPARTAMENTO','PROVINCIA','DISTRITO','UBIGEO','UUID']
fallecidos_df[columnas] = fallecidos_df['FECHA_CORTE;FECHA_FALLECIMIENTO;EDAD_DECLARADA;SEXO;CLASIFICACION_DEF;DEPARTAMENTO;PROVINCIA;DISTRITO;UBIGEO;UUID'].str.split(';', expand=True)

fallecidos_df = fallecidos_df.drop(columns=['FECHA_CORTE;FECHA_FALLECIMIENTO;EDAD_DECLARADA;SEXO;CLASIFICACION_DEF;DEPARTAMENTO;PROVINCIA;DISTRITO;UBIGEO;UUID'])
fallecidos_df['FECHA_FALLECIMIENTO'] = pd.to_datetime(fallecidos_df['FECHA_FALLECIMIENTO'], format='%Y%m%d', errors='coerce')

fallecidos_df['YearMonth'] = fallecidos_df['FECHA_FALLECIMIENTO'].dt.strftime('%Y-%m')

reporte_mensual = fallecidos_df.groupby('YearMonth')['UUID'].count().reset_index()

reporte_mensual.columns = ['YearMonth', 'Fallecidos']
styled_reporte_mensual = reporte_mensual.style.format({'Fallecidos': lambda x: f"{x:,.0f}" if x >= 1000 else f"{x}"})

styled_reporte_mensual.to_excel('styled_reporte_mensual.xlsx', index=False)  # Guardar en Excel
styled_reporte_mensual
# Out:
# <style type="text/css">
# </style>
# <table id="T_6e295" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e295_level0_col0" class="col_heading level0 col0" >YearMonth</th>
#       <th id="T_6e295_level0_col1" class="col_heading level0 col1" >Fallecidos</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e295_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6e295_row0_col0" class="data row0 col0" >2020-03</td>
#       <td id="T_6e295_row0_col1" class="data row0 col1" >181</td>
#     </tr>
#     <tr>
#       <th id="T_6e295_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6e295_row1_col0" class="data row1 col0" >2020-04</td>
#       <td id="T_6e295_row1_col1" class="data row1 col1" >5,134</td>
#     </tr>
#     <tr>
#       <th id="T_6e295_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6e295_row2_col0" class="data row2 col0" >2020-05</td>
# ...

# %%
import pandas as pd

fallecidos_df = pd.read_csv('fallecidosCOVID.csv')

columnas = ['FECHA_CORTE','FECHA_FALLECIMIENTO','EDAD_DECLARADA','SEXO','CLASIFICACION_DEF','DEPARTAMENTO','PROVINCIA','DISTRITO','UBIGEO','UUID']
fallecidos_df[columnas] = fallecidos_df['FECHA_CORTE;FECHA_FALLECIMIENTO;EDAD_DECLARADA;SEXO;CLASIFICACION_DEF;DEPARTAMENTO;PROVINCIA;DISTRITO;UBIGEO;UUID'].str.split(';', expand=True)

fallecidos_df = fallecidos_df.drop(columns=['FECHA_CORTE;FECHA_FALLECIMIENTO;EDAD_DECLARADA;SEXO;CLASIFICACION_DEF;DEPARTAMENTO;PROVINCIA;DISTRITO;UBIGEO;UUID'])

fallecidos_df['FECHA_FALLECIMIENTO'] = pd.to_datetime(fallecidos_df['FECHA_FALLECIMIENTO'], format='%Y%m%d', errors='coerce')

fallecidos_df['YearMonth'] = fallecidos_df['FECHA_FALLECIMIENTO'].dt.strftime('%Y-%m')

reporte_mensual = pd.pivot_table(fallecidos_df, values='UUID', index='YearMonth', columns='CLASIFICACION_DEF', aggfunc='count', fill_value=0)

reporte_mensual = reporte_mensual.rename(columns={'UUID': 'Fallecidos'})
reporte_mensual=reporte_mensual.iloc[:,[0,1,2,3,4,6]]

reporte_mensual
# Out:
# CLASIFICACION_DEF  Criterio SINADEF  Criterio clínico  \
# YearMonth
# 2020-03                          35                52
# 2020-04                        1793               541
# 2020-05                        6826              1152
# 2020-06                        5722               670
# 2020-07                        5012               609
# 2020-08                        4589               611
# 2020-09                        1984               475
# 2020-10                        1091               463
# 2020-11                         704               462
# 2020-12                         802               547
# 2021-01                        2190               514
# 2021-02                        4993               501
# 2021-03                        6100               525
# 2021-04                        7450               748
# 2021-05                        5225               628
# 2021-06                        2723               116
# ...
